# %%
import pandas as pd

# %%
filepath="C:/Users/claudio.pacheco/Documents/GitHub/medscraper/medscraper/listado/precios_max_brasil.xls"
df=pd.read_excel(filepath,skiprows=44, 
                 #Renombrar columnas
                 usecols=[0,8,9,28],names=['sustancia', 'producto', 'presentacion','precio'])
df.columns=df.columns.str.lower()
#Drop registros con NaN en precio
df=df.dropna(subset=['precio'])
#Cambiar comas por puntos en precio
df['precio']=df['precio'].str.replace(',','.')
df['precio']=df['precio'].astype(float)
df
# Out:
#                                                sustancia  \
# 0                                     VALPROATO DE SÓDIO
# 1      SALICILATO DE FENILA;ÁCIDO SALICÍLICO;ÓXIDO DE...
# 2                       DIENOGESTE;VALERATO DE ESTRADIOL
# 3                                           MONTELUCASTE
# 4                                           MONTELUCASTE
# ...                                                  ...
# 28601                                         VENETOCLAX
# 28603                                     RISANQUIZUMABE
# 28604                       UPADACITINIBE HEMI-HIDRATADO
# 28605                       UPADACITINIBE HEMI-HIDRATADO
# 28610                                    INSULINA HUMANA
#
#                            producto  \
# 0                   ÁCIDO VALPRÓICO
# 1                      TALCO ALÍVIO
# 2                         CHARMELIE
# 3                         SINGULAIR
# 4                         SINGULAIR
# ...                             ...
# 28601                     VENCLEXTA
# 28603                       SKYRIZI
# 28604                        RINVOQ
# 28605                        RINVOQ
# 28610  BAHIAFARMA INSULINA HUMANA R
#
#                                             presentacion    precio
# 0                 250 MG CAP GEL MOLE CT FR VD AMB X 100     63.45
# 1                                     TALQUEIRA C/ 100 G      9.30
# 2      COM REV A + COM REV B + COM REV C + COM REV D ...    198.09
# 3                 5 MG COM MAST CT 3 BL AL PLAS INC X 10     87.11
# 4                 10 MG COM REV CT 3 BL AL PLAS INC X 10     87.11
# ...                                                  ...       ...
# 28601              50 MG COM REV CT BL AL PLAS TRANS X 7   1776.42
# 28603  75 MG SOL INJ CT 2 BL X SER PREENC VD TRANS X ...  28547.97
# 28604    15 MG COM REV LIB PROL CT FR PLAS PEAD OPC X 30   7537.21
# 28605  15 MG COM REV LIB PROL CT 3 FR PLAS PEAD OPC X 30  22611.65
# 28610             100 UI/ML SOL INJ CT FA VD INC X 10 ML     63.21
#
# [23548 rows x 4 columns]
